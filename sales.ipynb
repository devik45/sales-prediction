# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv(r"H:\space\advertising.csv")
sales
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
sales.shape
# Out:
# (200, 4)

# %%
sales.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sales.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sns.pairplot(sales, x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind='scatter')
plt.show()

# %%
sales['TV'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Radio'].plot.hist(bins=10,color="black",xlabel="Radio")
# Out:
# <Axes: xlabel='Radio', ylabel='Frequency'>

# %%
sales['Newspaper'].plot.hist(bins=10,color="pink",xlabel="newspaper")
# Out:
# <Axes: xlabel='newspaper', ylabel='Frequency'>

# %%
sns.heatmap(sales.corr(),annot = True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(sales[['TV']], sales[['Sales']], test_size = 0.3,random_state = 0)

# %%
print(x_train)
# Out:
#         TV
# 131  265.2
# 96   197.6
# 181  218.5
# 19   147.3
# 153  171.3
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [140 rows x 1 columns]

# %%
print(y_train)
# Out:
#      Sales
# 131   17.7
# 96    16.7
# 181   17.2
# 19    14.6
# 153   16.0
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [140 rows x 1 columns]

# %%
print(x_test)
# Out:
#         TV
# 18    69.2
# 170   50.0
# 107   90.4
# 98   289.7
# 177  170.2
# 182   56.2
# 5      8.7
# 146  240.1
# 12    23.8
# 152  197.6
# 61   261.3
# 125   87.2
# 180  156.6
# 154  187.8
# 80    76.4
# 7    120.2
# 33   265.6
# 130    0.7
# 37    74.7
# 74   213.4
# 183  287.6
# 145  140.3
# 45   175.1
# 159  131.7
# 60    53.5
# 123  123.1
# 179  165.6
# 185  205.0
# 122  224.0
# 44    25.1
# 16    67.8
# 55   198.9
# 150  280.7
# 111  241.7
# 22    13.2
# 189   18.7
# 129   59.6
# 4    180.8
# 83    68.4
# 106   25.0
# 134   36.9
# 66    31.5
# 26   142.9
# 113  209.6
# 168  215.4
# 63   102.7
# 8      8.6
# 75    16.9
# 118  125.7
# 143  104.6
# 71   109.8
# 124  229.5
# 184  253.8
# 97   184.9
# 149   44.7
# 24    62.3
# 30   292.9
# 160  172.5
# 40   202.5
# 56     7.3

# %%
print(y_test)
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# 5      7.2
# 146   18.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   15.5
# 154   20.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    16.1
# 159   12.9
# 60     8.1
# 123   15.2
# 179   17.6
# 185   22.6
# 122   16.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     17.9
# 83    13.6
# 106    7.2
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# 63    14.0
# 8      4.8
# 75     8.7
# 118   15.9
# 143   10.4
# 71    12.4
# 124   19.7
# 184   17.6
# 97    20.5
# 149   10.1
# 24     9.7
# 30    21.4
# 160   16.4
# 40    16.6
# 56     5.5

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sal= model.predict(x_train)
print(sal)
# Out:
# [[21.65874695]
#  [17.95886418]
#  [19.10276285]
#  [15.20584491]
#  [16.51941275]
#  [19.05897726]
#  [21.52191697]
#  [16.0925032 ]
#  [12.63891441]
#  [11.31987336]
#  [17.26376787]
#  [14.49432899]
#  [22.1239689 ]
#  [23.36638515]
#  [12.40904004]
#  [13.15339515]
#  [21.12237341]
#  [18.31462214]
#  [20.28497391]
#  [17.74540941]
#  [17.60310623]
#  [12.05328208]
#  [ 9.49729798]
#  [ 9.23458441]
#  [ 7.86081137]
#  [20.24118832]
#  [ 8.08521254]
#  [18.6758533 ]
#  [ 8.54496129]
#  [16.83138512]
#  [18.46787172]
#  [10.76160703]
#  [15.33720169]
#  [14.22614222]
#  [12.29957605]
#  [22.28816488]
#  [22.29911127]
#  [ 7.5707318 ]
#  [20.87607944]
#  [16.76023352]
#  [ 7.78418658]
#  [11.27608777]
#  [18.07927457]
#  [19.73765398]
#  [13.02203836]
#  [19.5023064 ]
#  [16.0815568 ]
#  [14.31918661]
#  [18.46239853]
#  [16.83138512]
#  [19.00971846]
#  [10.80539262]
#  [19.57893119]
#  [17.71804341]
#  [12.48019163]
#  [11.8343541 ]
#  [19.63913639]
#  [14.77893536]
# ...

# %%
plt.plot(sal)

# %%
plt.scatter(x_train,sal)
plt.show()

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,6.948 + 0.054 * x_test,'r')
plt.show()
